# %%
# Step 1
import warnings
warnings.filterwarnings("ignore")

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,precision_recall_fscore_support
from sklearn.metrics import f1_score,roc_auc_score
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('./CICIDS-7-flows.csv') 
start_time = time.time()

# %%
df
# Out:
#         Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0          65511209.0                6.0                     6.0
# 1          67037196.0                8.0                     8.0
# 2          67987663.0                6.0                     6.0
# 3          72017628.0                8.0                     8.0
# 4          96404610.0               58.0                    33.0
# ...               ...                ...                     ...
# 687102       119835.0                1.0                     1.0
# 687103       155149.0                1.0                     1.0
# 687104            4.0                2.0                     0.0
# 687105          125.0                2.0                     2.0
# 687106            3.0                2.0                     0.0
#
#         Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                             288.0                        288.0
# 1                             384.0                        384.0
# 2                             288.0                        288.0
# 3                             384.0                        384.0
# 4                           12242.0                       8238.0
# ...                             ...                          ...
# 687102                         45.0                        103.0
# 687103                         45.0                        140.0
# 687104                        124.0                          0.0
# 687105                         96.0                         96.0
# 687106                          0.0                          0.0
#
#         Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                        48.0                   48.0               48.000000
# 1                        48.0                   48.0               48.000000
# 2                        48.0                   48.0               48.000000
# 3                        48.0                   48.0               48.000000
# 4                      1337.0                    0.0              211.068966
# ...                       ...                    ...                     ...
# 687102                   45.0                   45.0               45.000000
# 687103                   45.0                   45.0               45.000000
# 687104                   62.0                   62.0               62.000000
# 687105                   48.0                   48.0               48.000000
# 687106                    0.0                    0.0                0.000000
#
#         Fwd Packet Length Std  Bwd Packet Length Max  ...  \
# 0                     0.00000                   48.0  ...
# 1                     0.00000                   48.0  ...
# 2                     0.00000                   48.0  ...
# 3                     0.00000                   48.0  ...
# 4                   287.25341                 3069.0  ...
# ...                       ...                    ...  ...
# 687102                0.00000                  103.0  ...
# 687103                0.00000                  140.0  ...
# 687104                0.00000                    0.0  ...
# 687105                0.00000                   48.0  ...
# 687106                0.00000                    0.0  ...
#
#         min_seg_size_forward  Active Mean    Active Std  Active Max  \
# 0                       20.0    1506210.0  0.000000e+00   1506210.0
# 1                        8.0   11034681.0  0.000000e+00  11034681.0
# 2                       20.0     996497.0  0.000000e+00    996497.0
# 3                        8.0   15016472.0  0.000000e+00  15016472.0
# 4                       32.0    3124660.0  3.965763e+06   8266119.0
# ...                      ...          ...           ...         ...
# 687102                  20.0          0.0  0.000000e+00         0.0
# 687103                  20.0          0.0  0.000000e+00         0.0
# 687104                  32.0          0.0  0.000000e+00         0.0
# 687105                  20.0          0.0  0.000000e+00         0.0
# 687106                  32.0          0.0  0.000000e+00         0.0
#
#         Active Min    Idle Mean      Idle Std    Idle Max    Idle Min   Label
# 0        1506210.0  64004884.00  0.000000e+00  64004884.0  64004884.0  BENIGN
# 1       11034681.0  55956316.00  0.000000e+00  55956316.0  55956316.0  BENIGN
# 2         996497.0  66991029.00  0.000000e+00  66991029.0  66991029.0  BENIGN
# 3       15016472.0  56970996.00  0.000000e+00  56970996.0  56970996.0  BENIGN
# 4            386.0  20976398.75  2.298942e+07  54036735.0   5025593.0  BENIGN
# ...            ...          ...           ...         ...         ...     ...
# 687102         0.0         0.00  0.000000e+00         0.0         0.0  BENIGN
# 687103         0.0         0.00  0.000000e+00         0.0         0.0  BENIGN
# 687104         0.0         0.00  0.000000e+00         0.0         0.0  BENIGN
# 687105         0.0         0.00  0.000000e+00         0.0         0.0  BENIGN
# 687106         0.0         0.00  0.000000e+00         0.0         0.0  BENIGN
#
# [687107 rows x 77 columns]

# %%
df['Label'].unique()

labels = {'BENIGN', 'DDoS', 'DoS Hulk', 'FTP-Patator', 'SSH-Patator'}
df = df[df['Label'].isin(labels)]

# %%
df['Label'].value_counts()
# Out:
# BENIGN         349107
# DoS Hulk       229705
# DDoS            84396
# FTP-Patator      7752
# SSH-Patator      5854
# Name: Label, dtype: int64

# %%
# Z-score normalization

df['Label'] = df['Label'].astype('object')

features = df.dtypes[df.dtypes != 'object'].index
df[features] = df[features].apply(
    lambda x: (x - x.mean()) / (x.std()))
# Fill empty values by 0
df = df.fillna(0)

# %%
labelencoder = LabelEncoder()
df.iloc[:, -1] = labelencoder.fit_transform(df.iloc[:, -1])

# %%
df.to_csv('./CICIDS_final_baseline.csv',index=False)   # was 'CICIDS_paper_subset_downsampledBenign_z_normalized.csv'

# %%
# retain the minority class instances and sample the majority class instances
df_minor = df[(df['Label']==3)|(df['Label']==4)]
df_major = df.drop(df_minor.index)

# %%
X = df_major.drop(['Label'],axis=1) 
y = df_major.iloc[:, -1].values.reshape(-1,1)
y=np.ravel(y)

# %%
# use k-means to cluster the data samples and select a proportion of data from each cluster
from sklearn.cluster import MiniBatchKMeans
kmeans = MiniBatchKMeans(n_clusters=1000, random_state=0).fit(X)

# %%
klabel=kmeans.labels_
df_major['klabel']=klabel

# %%
df_major['klabel'].value_counts()
# Out:
# 546    9343
# 0      6922
# 4      6607
# 357    5856
# 808    4412
#        ...
# 232      10
# 487      10
# 943       9
# 310       9
# 203       4
# Name: klabel, Length: 994, dtype: int64

# %%
cols = list(df_major)
cols.insert(78, cols.pop(cols.index('Label')))
df_major = df_major.loc[:, cols]

# %%
df_major
# Out:
#         Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0            0.905281          -0.001712               -0.002260
# 1            0.941962           0.001887                0.000401
# 2            0.964809          -0.001712               -0.002260
# 3            1.061681           0.001887                0.000401
# 4            1.647889           0.091852                0.033652
# ...               ...                ...                     ...
# 687102      -0.666581          -0.010708               -0.008910
# 687103      -0.665732          -0.010708               -0.008910
# 687104      -0.669461          -0.008909               -0.010240
# 687105      -0.669458          -0.008909               -0.007580
# 687106      -0.669461          -0.008909               -0.010240
#
#         Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                         -0.043944                    -0.007894
# 1                         -0.027245                    -0.007835
# 2                         -0.043944                    -0.007894
# 3                         -0.027245                    -0.007835
# 4                          2.035431                    -0.003014
# ...                             ...                          ...
# 687102                    -0.086213                    -0.008008
# 687103                    -0.086213                    -0.007985
# 687104                    -0.072471                    -0.008071
# 687105                    -0.077342                    -0.008012
# 687106                    -0.094041                    -0.008071
#
#         Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                   -0.213954               0.260959               -0.148888
# 1                   -0.213954               0.260959               -0.148888
# 2                   -0.213954               0.260959               -0.148888
# 3                   -0.213954               0.260959               -0.148888
# 4                    0.933074              -0.368658                0.393395
# ...                       ...                    ...                     ...
# 687102              -0.216624               0.221608               -0.158864
# 687103              -0.216624               0.221608               -0.158864
# 687104              -0.201496               0.444597               -0.102331
# 687105              -0.213954               0.260959               -0.148888
# 687106              -0.256668              -0.368658               -0.308511
#
#         Fwd Packet Length Std  Bwd Packet Length Max  ...  Active Mean  \
# 0                   -0.226821              -0.645426  ...     2.531753
# 1                   -0.226821              -0.645426  ...    19.305200
# 2                   -0.226821              -0.645426  ...     1.634480
# 3                   -0.226821              -0.645426  ...    26.314547
# 4                    0.376629               0.334022  ...     5.380792
# ...                       ...                    ...  ...          ...
# 687102              -0.226821              -0.627594  ...    -0.119704
# 687103              -0.226821              -0.615598  ...    -0.119704
# 687104              -0.226821              -0.660988  ...    -0.119704
# 687105              -0.226821              -0.645426  ...    -0.119704
# 687106              -0.226821              -0.660988  ...    -0.119704
#
#         Active Std  Active Max  Active Min  Idle Mean  Idle Std  Idle Max  \
# 0        -0.029505    1.977578    2.682155   0.967979 -0.178118  0.917289
# 1        -0.029505   15.175870   20.395345   0.765190 -0.178118  0.719493
# 2        -0.029505    1.271553    1.734611   1.043216 -0.178118  0.990674
# 3        -0.029505   20.691219   27.797395   0.790755 -0.178118  0.744429
# 4        16.554593   11.341017   -0.117134  -0.116151  2.493613  0.672319
# ...            ...         ...         ...        ...       ...       ...
# 687102   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
# 687103   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
# 687104   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
# 687105   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
# 687106   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
#
#         Idle Min  klabel  Label
# 0       0.997378     614      0
# 1       0.794202     224      0
# 2       1.072760     614      0
# 3       0.819816     935      0
# 4      -0.491484      72      0
# ...          ...     ...    ...
# 687102 -0.618349     542      0
# 687103 -0.618349     758      0
# 687104 -0.618349     260      0
# 687105 -0.618349     507      0
# 687106 -0.618349     546      0
#
# [663208 rows x 78 columns]

# %%
def typicalSampling(group):
    name = group.name
    # frac = 0.008
    frac = 0.1
    return group.sample(frac=frac)

result = df_major.groupby(
    'klabel', group_keys=False
).apply(typicalSampling)

# %%
result['Label'].value_counts()
# Out:
# 0    34908
# 2    22979
# 1     8435
# Name: Label, dtype: int64

# %%
result
# Out:
#         Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 349865      -0.669461          -0.008909               -0.010240
# 220265      -0.669461          -0.008909               -0.010240
# 240604      -0.669461          -0.008909               -0.010240
# 323608      -0.669461          -0.008909               -0.010240
# 394245      -0.669461          -0.008909               -0.010240
# ...               ...                ...                     ...
# 380747       1.730174          -0.003511               -0.000929
# 206544       1.664318          -0.005310               -0.000929
# 288277       1.632354          -0.005310               -0.000929
# 284476       1.699046          -0.005310               -0.000929
# 302188       1.694294          -0.005310               -0.000929
#
#         Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 349865                    -0.094041                    -0.008071
# 220265                    -0.094041                    -0.008071
# 240604                    -0.094041                    -0.008071
# 323608                    -0.094041                    -0.008071
# 394245                    -0.094041                    -0.008071
# ...                             ...                          ...
# 380747                    -0.032289                    -0.000953
# 206544                    -0.023592                    -0.000953
# 288277                    -0.033507                    -0.000953
# 284476                    -0.039943                    -0.000953
# 302188                    -0.038029                    -0.000953
#
#         Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 349865              -0.256668              -0.368658               -0.308511
# 220265              -0.256668              -0.368658               -0.308511
# 240604              -0.256668              -0.368658               -0.308511
# 323608              -0.256668              -0.368658               -0.308511
# 394245              -0.256668              -0.368658               -0.308511
# ...                       ...                    ...                     ...
# 380747               0.048554              -0.368658               -0.072402
# 206544               0.098386              -0.368658                0.028194
# 288277               0.047664              -0.368658               -0.019194
# 284476               0.014739              -0.368658               -0.049955
# 302188               0.024528              -0.368658               -0.040810
#
#         Fwd Packet Length Std  Bwd Packet Length Max  ...  Active Mean  \
# 349865              -0.226821              -0.660988  ...    -0.119704
# 220265              -0.226821              -0.660988  ...    -0.119704
# 240604              -0.226821              -0.660988  ...    -0.119704
# 323608              -0.226821              -0.660988  ...    -0.119704
# 394245              -0.226821              -0.660988  ...    -0.119704
# ...                       ...                    ...  ...          ...
# 380747               0.092667               0.747393  ...    -0.100319
# 206544               0.190222               0.747393  ...    -0.119704
# 288277               0.130357               0.747393  ...    -0.119704
# 284476               0.091499               0.747393  ...    -0.119704
# 302188               0.103051               0.747393  ...    -0.119704
#
#         Active Std  Active Max  Active Min  Idle Mean  Idle Std  Idle Max  \
# 349865   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
# 220265   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
# 240604   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
# 323608   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
# 394245   -0.029505   -0.108737   -0.117852  -0.644664 -0.178118 -0.655647
# ...            ...         ...         ...        ...       ...       ...
# 380747   -0.029505   -0.093484   -0.097381   1.867339 -0.178118  1.794505
# 206544   -0.029505   -0.108737   -0.117852   1.799311 -0.178118  1.728152
# 288277   -0.029505   -0.108737   -0.117852   1.769076 -0.178118  1.698662
# 284476   -0.029505   -0.108737   -0.117852   1.834585 -0.178118  1.762557
# 302188   -0.029505   -0.108737   -0.117852   1.829545 -0.178118  1.757642
#
#         Idle Min  klabel  Label
# 349865 -0.618349       0      2
# 220265 -0.618349       0      2
# 240604 -0.618349       0      2
# 323608 -0.618349       0      2
# 394245 -0.618349       0      2
# ...          ...     ...    ...
# 380747  1.898459     999      2
# 206544  1.830301     999      2
# 288277  1.800009     999      2
# 284476  1.865643     999      2
# 302188  1.860594     999      2
#
# [66322 rows x 78 columns]

# %%
result = result.drop(['klabel'],axis=1)
result = result.append(df_minor)

# %%
result.to_csv('./CICIDS_final_baseline_undersampled.csv',index=0)

# %%
# Read the sampled dataset
df=pd.read_csv('./CICIDS_final_baseline_undersampled.csv')  # was './CICIDS_final_baseline.csv'

# %%
df
# Out:
#        Flow Duration  Total Fwd Packets  Total Backward Packets  \
# 0          -0.669461          -0.008909               -0.010240
# 1          -0.669461          -0.008909               -0.010240
# 2          -0.669461          -0.008909               -0.010240
# 3          -0.669461          -0.008909               -0.010240
# 4          -0.669461          -0.008909               -0.010240
# ...              ...                ...                     ...
# 79923      -0.342317           0.027077                0.032322
# 79924      -0.341255           0.027077                0.033652
# 79925      -0.340594           0.027077                0.033652
# 79926      -0.341932           0.027077                0.033652
# 79927      -0.341294           0.027077                0.033652
#
#        Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                        -0.094041                    -0.008071
# 1                        -0.094041                    -0.008071
# 2                        -0.094041                    -0.008071
# 3                        -0.094041                    -0.008071
# 4                        -0.094041                    -0.008071
# ...                            ...                          ...
# 79923                     0.255247                    -0.006386
# 79924                     0.255247                    -0.006386
# 79925                     0.255247                    -0.006386
# 79926                     0.255247                    -0.006386
# 79927                     0.255247                    -0.006386
#
#        Fwd Packet Length Max  Fwd Packet Length Min  Fwd Packet Length Mean  \
# 0                  -0.256668              -0.368658               -0.308511
# 1                  -0.256668              -0.368658               -0.308511
# 2                  -0.256668              -0.368658               -0.308511
# 3                  -0.256668              -0.368658               -0.308511
# 4                  -0.256668              -0.368658               -0.308511
# ...                      ...                    ...                     ...
# 79923               0.312842              -0.368658               -0.004985
# 79924               0.312842              -0.368658               -0.004985
# 79925               0.312842              -0.368658               -0.004985
# 79926               0.312842              -0.368658               -0.004985
# 79927               0.312842              -0.368658               -0.004985
#
#        Fwd Packet Length Std  Bwd Packet Length Max  ...  \
# 0                  -0.226821              -0.660988  ...
# 1                  -0.226821              -0.660988  ...
# 2                  -0.226821              -0.660988  ...
# 3                  -0.226821              -0.660988  ...
# 4                  -0.226821              -0.660988  ...
# ...                      ...                    ...  ...
# 79923               0.063466              -0.344556  ...
# 79924               0.063466              -0.344556  ...
# 79925               0.063466              -0.344556  ...
# 79926               0.063466              -0.344556  ...
# 79927               0.063466              -0.344556  ...
#
#        min_seg_size_forward  Active Mean  Active Std  Active Max  Active Min  \
# 0                  0.002696    -0.119704   -0.029505   -0.108737   -0.117852
# 1                  0.002696    -0.119704   -0.029505   -0.108737   -0.117852
# 2                  0.002696    -0.119704   -0.029505   -0.108737   -0.117852
# 3                  0.002696    -0.119704   -0.029505   -0.108737   -0.117852
# 4                  0.002696    -0.119704   -0.029505   -0.108737   -0.117852
# ...                     ...          ...         ...         ...         ...
# 79923              0.002696    -0.119704   -0.029505   -0.108737   -0.117852
# 79924              0.002696    -0.119704   -0.029505   -0.108737   -0.117852
# 79925              0.002696    -0.119704   -0.029505   -0.108737   -0.117852
# 79926              0.002696    -0.119704   -0.029505   -0.108737   -0.117852
# 79927              0.002696    -0.119704   -0.029505   -0.108737   -0.117852
#
#        Idle Mean  Idle Std  Idle Max  Idle Min  Label
# 0      -0.644664 -0.178118 -0.655647 -0.618349      2
# 1      -0.644664 -0.178118 -0.655647 -0.618349      2
# 2      -0.644664 -0.178118 -0.655647 -0.618349      2
# 3      -0.644664 -0.178118 -0.655647 -0.618349      2
# 4      -0.644664 -0.178118 -0.655647 -0.618349      2
# ...          ...       ...       ...       ...    ...
# 79923  -0.644664 -0.178118 -0.655647 -0.618349      4
# 79924  -0.644664 -0.178118 -0.655647 -0.618349      4
# 79925  -0.644664 -0.178118 -0.655647 -0.618349      4
# 79926  -0.644664 -0.178118 -0.655647 -0.618349      4
# 79927  -0.644664 -0.178118 -0.655647 -0.618349      4
#
# [79928 rows x 77 columns]

# %%
df['Label'] = df['Label'].astype('object')
features = df.dtypes[df.dtypes != 'object'].index
df['Label'] = df['Label'].astype('int')

# %%
X = df.drop(['Label'],axis=1).values
y = df.iloc[:, -1].values.reshape(-1,1)
y=np.ravel(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size = 0.8, test_size = 0.2, random_state = 0)

# %%
from sklearn.feature_selection import mutual_info_classif
importances = mutual_info_classif(X_train, y_train)

# %%
# calculate the sum of importance scores
f_list = sorted(zip(map(lambda x: round(x, 4), importances), features), reverse=True)
Sum = 0
fs = []
for i in range(0, len(f_list)):
    Sum = Sum + f_list[i][0]
    fs.append(f_list[i][1])

# %%
# select the important features from top to bottom until the accumulated importance reaches 90%
f_list2 = sorted(zip(map(lambda x: round(x, 4), importances/Sum), features), reverse=True)
Sum2 = 0
fs = []
for i in range(0, len(f_list2)):
    Sum2 = Sum2 + f_list2[i][0]
    fs.append(f_list2[i][1])
    if Sum2>=0.9:
        break

# %%
X_fs = df[fs].values

# %%
X_fs.shape
# Out:
# (79928, 46)

# %%
from FCBF_module import FCBF, FCBFK, FCBFiP, get_i
fcbf = FCBFK(k = 20)
#fcbf.fit(X_fs, y)

# %%
# 5 minutes
X_fss = fcbf.fit_transform(X_fs,y)

# %%
selected_features = fcbf.idx_sel

# %%
selected_features
# Out:
# [3, 28, 19, 16, 30, 31, 32, 33, 1, 6, 12, 13, 4, 5, 15, 11, 14, 34, 9, 10]

# %%
df['Label'].value_counts()
# Out:
# 0    34908
# 2    22979
# 1     8435
# 3     7752
# 4     5854
# Name: Label, dtype: int64

# %%
end_time = time.time()

print(f'Elapsed time: {end_time-start_time} seconds')
# Out:
# Elapsed time: 294.63885045051575 seconds
